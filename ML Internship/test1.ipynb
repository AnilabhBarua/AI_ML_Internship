# %%
import mysql.connector

dataBase=mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="Reeve4098"
)

cursorObject=dataBase.cursor()

cursorObject.execute("createDatabase GUIST")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 11
#       3 dataBase=mysql.connector.connect(
#       4     host="localhost",
#       5     user="root",
#       6     passwd="Reeve4098"
#       7 )
#       9 cursorObject=dataBase.cursor()
# ---> 11 cursorObject.execute("createDatabase GUIST")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\cursor.py:615, in MySQLCursor.execute(self, operation, params, multi)
#     612     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     614 try:
# --> 615     self._handle_result(self._connection.cmd_query(stmt))
#     616 except InterfaceError as err:
#     617     if self._connection.have_next_result:
#
# ...
